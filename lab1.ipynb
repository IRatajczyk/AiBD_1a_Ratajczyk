# %% [markdown]
# ## <center>Laboratorium 1</center>
# # <center>Analiza i bazy danych</center>
# <center>Igor Ratajczyk</center>
#
# Laboratorium 1
# Analiza i bazy danych
# Igor Ratajczyk

# %%
#import of necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Zadanie 3.
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danych przedziałów:
#
# $f(x)=x^2+5$
#
# * $-1<x<1$
#
# * $-6<x<6$
#
# * $0<x<5$

# %%
#definicja funkcji jako prostej funkcji lambda
fun = lambda x : x*x+5

#inicjalizacja dziedzin kolejnych funkcji
domain_1 = np.linspace(-1,1)
domain_2 = np.linspace(-6,6)
domain_3 = np.linspace(0,5)

#tworzenie subplotów
f, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(30,10))
f.suptitle('Comprehensive comparison exemplary plots')

#podaję dziedzinę, wartości, nazwę funkcji, dalej dla każdego subplota ustaaim tytuł, ograniczenia, labeluję osie
ax1.plot(domain_1,fun(domain_1),label=r'${f(x) = x^2 + 5}$')
ax1.set_title('First domain')
ax1.set_xlim([-1,1])
ax1.set_ylabel('y')
ax1.set_xlabel('x')
ax1.legend()

ax2.plot(domain_2,fun(domain_2),label=r'${f(x) = x^2 + 5}$')
ax2.set_title('Second domain')
ax2.set_xlim([-6,6])
ax2.set_ylabel('y')
ax2.set_xlabel('x')
ax2.legend()

ax3.plot(domain_3,fun(domain_3),label=r'${f(x) = x^2 + 5}$')
ax3.set_title('Third domain')
ax3.set_xlim([0, 5])
ax3.set_ylabel('y')
ax3.set_xlabel('x')
ax3.legend()


plt.show()

# %% [markdown]
# # Zadanie 4.

# %%
DF=pd.DataFrame({'name':['Igor','Sara','Jan','Michał','Magda'],
            'surname':['Nowak','Kowalska','Kowalski','Filipek','Koniecpolska'],
            'age':[20,17,23,40,32],
            'sex':['Male','Female','Male','Female','Male']
            })
#tworzę dataframe podając do konstruktra słownik, gdzie kluczem jest nazwa kolumny
#wyświetlam podstawowe informacje o Dataframe

DF.info()
DF.describe()
DF.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
# name       5 non-null object
# surname    5 non-null object
# age        5 non-null int64
# sex        5 non-null object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
#    name   surname  age     sex
# 0  Igor     Nowak   20    Male
# 1  Sara  Kowalska   17  Female
# 2   Jan  Kowalski   23    Male
